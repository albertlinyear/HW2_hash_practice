# %%
import os
import matplotlib.pyplot as plt

def read_words(file_path):
    word_count = {}  # hash table 初始化
    if not os.path.exists(file_path):
        raise FileNotFoundError(f"找不到檔案：{file_path}")

    with open(file_path, 'r', encoding='utf-8') as f:
        for line in f:
            word = line.strip()
            if word:
                if word in word_count:
                    word_count[word] += 1
                else:
                    word_count[word] = 1
    return word_count

# 顯示統計資訊
def print_word_stats(word_count):
    print(f"不重複的英文字總共有：{len(word_count)} 個")
    print("\n每個英文字的出現次數：")
    for word, count in word_count.items():
        print(f"{word}: {count}")

# 繪製直方圖
def plot_histogram(word_count):
    sorted_items = sorted(word_count.items(), key=lambda x: x[1], reverse=True)
    words = [item[0] for item in sorted_items]
    counts = [item[1] for item in sorted_items]

    plt.figure(figsize=(10, 6))
    plt.bar(words, counts, color='skyblue', edgecolor='black')
    plt.title("🍟 Word Frequency Histogram", fontsize=16)
    plt.xlabel("Words", fontsize=12)
    plt.ylabel("Frequency", fontsize=12)
    plt.xticks(rotation=45)
    plt.grid(axis='y', linestyle='--', alpha=0.5)
    plt.tight_layout()
    plt.savefig("Figure_1.png")
    plt.show()

# 主程式入口
if __name__ == "__main__":
    file_path = "hw2_data.txt"
    word_count = read_words(file_path)
    print_word_stats(word_count)
    plot_histogram(word_count)
# Out:
# 不重複的英文字總共有：10 個
#
# 每個英文字的出現次數：
# Cheese: 234
# Pizza: 83
# Coke: 145
# Steak: 46
# Burger: 196
# Fries: 76
# Rib: 33
# Taco: 57
# Pho: 19
# Potato: 3
# <ipython-input-10-b95b169e21fe>:39: UserWarning: Glyph 127839 (\N{FRENCH FRIES}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-10-b95b169e21fe>:40: UserWarning: Glyph 127839 (\N{FRENCH FRIES}) missing from font(s) DejaVu Sans.
#   plt.savefig("Figure_1.png")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-8-d5df0069828e> in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.11/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.11/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     135   )
#     136   if ephemeral:
# --> 137     _message.blocking_request(
#     138         'request_auth',
#     139         request={'authType': 'dfs_ephemeral'},
#
# ...
